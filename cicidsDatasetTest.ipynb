# %% [markdown]
# <a href="https://colab.research.google.com/github/j-hossain/crlab/blob/main/cicidsDatasetTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
